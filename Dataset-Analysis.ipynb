# %% [markdown]
# <h1 style="font-family: Trebuchet MS; padding: 12px; font-size: 30px; color: #081c15; text-align: center; line-height: 1.25;">🎥Analyzing the Disney Dataset📹</b></span><br><span style="color: #52b788; font-size: 20px">📀Explaratory data analysis/Data Wrangling/Plotting</span></h1>
# <hr>

# %% [markdown]
# <h2><span style="color: black; font-size: 2em; background:#EDF5FC; height: 100px; width: 100%; text-align:center"> <span style="color: Red" >E</span>sen <span style="color: Red" >G</span>ani</span></h2>

# %% [markdown]
# <blockquote><i><span style="background: #f8ffe"> "DS-221M"</span></i></blockquote>

# %% [markdown]
# ### Analysis of Dataset

# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set_style('white')
# %matplotlib inline

# %%
df = pd.read_csv('disney_movie_data_final.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0                            title  \
# 0           0  Snow White and the Seven Dwarfs
# 1           1                        Pinocchio
# 2           2                         Fantasia
# 3           3             The Reluctant Dragon
# 4           4                            Dumbo
#
#                                          Directed by  \
# 0  ['David Hand', 'William Cottrell', 'Wilfred Ja...
# 1  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 2  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 3  ['Alfred Werker', '(live action)', 'Hamilton L...
# 4  ['Ben Sharpsteen', 'Norman Ferguson', 'Wilfred...
#
#                                           Written by  \
# 0  ['Ted Sears', 'Richard Creedon', 'Otto England...
# 1                                                NaN
# 2                                                NaN
# 3  ['Live-action:', 'Ted Sears', 'Al Perkins', 'L...
# 4                                                NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'Directed by', 'Written by', 'Based on',
#        'Produced by', 'Starring', 'Music by', 'Production company',
#        'Distributed by', 'Release dates', 'Running time', 'Country',
#        'Language', 'Budget', 'Box office', 'Running time (int)',
#        'Budget (float)', 'Box office (float)', 'Release date (datetime)',
#        'imdb', 'metascore', 'rotten_tomatoes', 'genre', 'runtime', 'director',
#        'released', 'type', 'rated', 'Plot', 'Story by', 'Narrated by',
#        'Cinematography', 'Release date', 'Edited by', 'Languages',
#        'Screenplay by', 'Countries', 'Color process', 'Production companies',
#        'Japanese', 'Hepburn', 'Adaptation by', 'Animation by', 'Traditional',
#        'Simplified', 'Original title', 'Layouts by', 'Music', 'Lyrics', 'Book',
#        'Basis', 'Productions', 'Awards'],
#       dtype='object')

# %%
data2 = df.drop(columns=['Based on','Directed by', 'Written by','Music', 'Lyrics', 'Book',
       'Basis', 'Productions', 'Awards','Story by', 'Narrated by',
       'Cinematography','Edited by', 'Languages',
       'Screenplay by', 'Countries', 'Color process', 'Production companies',
       'Japanese', 'Hepburn', 'Adaptation by', 'Animation by', 'Traditional',
       'Simplified', 'Original title', 'Layouts by','Production company',
       'Distributed by','Produced by', 'Language', 'Music by'])

# %%
data2
# Out:
#      Unnamed: 0                            title  \
# 0             0  Snow White and the Seven Dwarfs
# 1             1                        Pinocchio
# 2             2                         Fantasia
# 3             3             The Reluctant Dragon
# 4             4                            Dumbo
# ..          ...                              ...
# 517         517                   The Aristocats
# 518         518           The Sword in the Stone
# 519         519                      Tinker Bell
# 520         520                    The Rocketeer
# 521         521          Young Woman and the Sea
#
#                                               Starring  \
# 0    ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 1    ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 2                ['Leopold Stokowski', 'Deems Taylor']
# 3    ['Robert Benchley', 'Frances Gifford', 'Buddy ...
# 4    ['Edward Brophy', 'Verna Felton', 'Cliff Edwar...
# ...

# %%
data2[['Release date','Release dates', 'released']].head(5)
# Out:
#             Release date                                      Release dates  \
# 0                    NaN  ['December 21, 1937 ( Carthay Circle Theatre )...
# 1                    NaN  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 2  ['November 13, 1940']                                                NaN
# 3      ['June 27, 1941']                                                NaN
# 4                    NaN  ['October 23, 1941 (New York City)', 'October ...
#
#       released
# 0  04 Feb 1938
# 1  23 Feb 1940
# 2  19 Sep 1941
# 3  20 Jun 1941
# 4  31 Oct 1941

# %%
print (data2['Release date'].isna().sum())
print (data2['Release dates'].isna().sum())
print (data2['released'].isna().sum())
print (data2['Box office'].isna().sum())
print (data2['Box office (float)'].isna().sum())
print (data2['Running time'].isna().sum())
print (data2['Running time (int)'].isna().sum())
# Out:
# 193
# 334
# 21
# 121
# 129
# 15
# 15

# %%
data2.drop(columns=['Release date', 'Release dates', 'Box office', 'Running time', 'Budget'])
# Out:
#      Unnamed: 0                            title  \
# 0             0  Snow White and the Seven Dwarfs
# 1             1                        Pinocchio
# 2             2                         Fantasia
# 3             3             The Reluctant Dragon
# 4             4                            Dumbo
# ..          ...                              ...
# 517         517                   The Aristocats
# 518         518           The Sword in the Stone
# 519         519                      Tinker Bell
# 520         520                    The Rocketeer
# 521         521          Young Woman and the Sea
#
#                                               Starring        Country  \
# 0    ['Adriana Caselotti', 'Lucille La Verne', 'Har...  United States
# 1    ['Cliff Edwards', 'Dickie Jones', 'Christian R...  United States
# 2                ['Leopold Stokowski', 'Deems Taylor']  United States
# 3    ['Robert Benchley', 'Frances Gifford', 'Buddy ...  United States
# ...

# %%
data2.isna().sum()
# Out:
# Unnamed: 0                   0
# title                        2
# Starring                    39
# Release dates              334
# Running time                15
# Country                     60
# Budget                     201
# Box office                 121
# Running time (int)          15
# Budget (float)             207
# Box office (float)         129
# Release date (datetime)    198
# imdb                        25
# metascore                  191
# rotten_tomatoes            141
# genre                       17
# runtime                     24
# director                    23
# released                    21
# type                        17
# rated                       33
# Plot                        20
# Release date               193
# dtype: int64

# %%
df2=data2.to_csv("Dropped columns.csv")

# %%
df2=pd.read_csv("Dropped columns.csv")

# %%
import missingno 
missingno.bar(df2,fontsize=10,figsize=(10,5))
plt.title('missing values in each column',fontsize=20)
# Out:
# Text(0.5, 1.0, 'missing values in each column')

# %%
df2
# Out:
#                                title  \
# 0    Snow White and the Seven Dwarfs
# 1                          Pinocchio
# 2                           Fantasia
# 3               The Reluctant Dragon
# 4                              Dumbo
# ..                               ...
# 517                   The Aristocats
# 518           The Sword in the Stone
# 519                      Tinker Bell
# 520                    The Rocketeer
# 521          Young Woman and the Sea
#
#                                               Starring  \
# 0    ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 1    ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 2                ['Leopold Stokowski', 'Deems Taylor']
# 3    ['Robert Benchley', 'Frances Gifford', 'Buddy ...
# 4    ['Edward Brophy', 'Verna Felton', 'Cliff Edwar...
# ..                                                 ...
# 517  ['Phil Harris', 'Eva Gabor', 'Sterling Hollowa...
# 518  ['Rickie Sorensen', 'Karl Swenson', 'Junius Ma...
# ...

# %%
df2.isnull().sum()
# Out:
# title                        2
# Starring                    39
# Release dates              334
# Running time                15
# Country                     60
# Budget                     201
# Box office                 121
# Running time (int)          15
# Budget (float)             207
# Box office (float)         129
# Release date (datetime)    198
# imdb                        25
# metascore                  191
# rotten_tomatoes            141
# genre                       17
# runtime                     24
# director                    23
# released                    21
# type                        17
# rated                       33
# Plot                        20
# Release date               193
# dtype: int64

# %%
df2.head(5)
# Out:
#                              title  \
# 0  Snow White and the Seven Dwarfs
# 1                        Pinocchio
# 2                         Fantasia
# 3             The Reluctant Dragon
# 4                            Dumbo
#
#                                             Starring  \
# 0  ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 1  ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 2              ['Leopold Stokowski', 'Deems Taylor']
# 3  ['Robert Benchley', 'Frances Gifford', 'Buddy ...
# 4  ['Edward Brophy', 'Verna Felton', 'Cliff Edwar...
#
#                                        Release dates Running time  \
# 0  ['December 21, 1937 ( Carthay Circle Theatre )...   83 minutes
# 1  ['February 7, 1940 ( Center Theatre )', 'Febru...   88 minutes
# 2                                                NaN  126 minutes
# 3                                                NaN   74 minutes
# 4  ['October 23, 1941 (New York City)', 'October ...   64 minutes
#
# ...

# %%
df2.drop("Unnamed:0", axis=1)

# %%
df['genre'].value_counts()
# Out:
# Animation, Adventure, Comedy                            84
# Adventure, Comedy, Family                               26
# Comedy, Drama, Family                                   24
# Adventure, Family, Fantasy                              20
# Adventure, Drama, Family                                19
#                                                         ..
# Adventure, Family, Sci-Fi                                1
# Animation, Adventure, Comedy, Family, Fantasy, Music     1
# Comedy, Mystery, Thriller                                1
# Action, Crime, Drama                                     1
# Adventure, Biography, Family                             1
# Name: genre, Length: 108, dtype: int64

# %%
df2 = df2.rename(columns={"genre":"Genre"})
df2['Genre'] = df2['Genre'].apply(lambda x: str(x).split(",")[0])
df2['Genre'].head(5)
# Out:
# 0    Animation
# 1    Animation
# 2    Animation
# 3    Animation
# 4    Animation
# Name: Genre, dtype: object

# %%
df['type'].value_counts()
# Out:
# movie     501
# series      4
# Name: type, dtype: int64

# %%
df['rated'].value_counts()
# Out:
# G            202
# PG           197
# Approved      40
# PG-13         20
# Not Rated     11
# Passed         9
# TV-14          3
# R              3
# TV-PG          1
# Unrated        1
# TV-MA          1
# TV-G           1
# Name: rated, dtype: int64

# %%
movie_df = df2[df2['type'] == 'movie']
tv_df = df2[df2['type'] == 'series']

# %%
movie_df.head()
# Out:
#                              title  \
# 0  Snow White and the Seven Dwarfs
# 1                        Pinocchio
# 2                         Fantasia
# 3             The Reluctant Dragon
# 4                            Dumbo
#
#                                             Starring  \
# 0  ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 1  ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 2              ['Leopold Stokowski', 'Deems Taylor']
# 3  ['Robert Benchley', 'Frances Gifford', 'Buddy ...
# 4  ['Edward Brophy', 'Verna Felton', 'Cliff Edwar...
#
#                                        Release dates Running time  \
# 0  ['December 21, 1937 ( Carthay Circle Theatre )...   83 minutes
# 1  ['February 7, 1940 ( Center Theatre )', 'Febru...   88 minutes
# 2                                                NaN  126 minutes
# 3                                                NaN   74 minutes
# 4  ['October 23, 1941 (New York City)', 'October ...   64 minutes
#
# ...

# %% [markdown]
# ##  Exploratory Data Analysis

# %%
import seaborn as sb

# %%
sb.countplot(x="type", data= df2, palette="Set2")

# %%
#number of movies & show 
plt.figure(figsize=(12,10))
sb.countplot(x="rated", data= movie_df, palette="Set2", order=movie_df['rated'].value_counts().index[0:15])

# %%
# adult = movie_df['rated'=='R'] & (movie_df['rated'=='Approved'])
conditions = [
    movie_df['rated']=='G',
    movie_df['rated']=='PG',
    movie_df['rated']=='PG-13',
    movie_df['rated']=='TV-14',
    movie_df['rated']=='TV-G',
]

# %%
outputs = [
    'G', 'PG', 'PG-13', 'TV-14', 'TV-G'
]

# %%
non_adult = np.select(conditions, outputs)

# %%
conditions = [
    movie_df['rated']=='Passed'
    movie_df['rated']=='Not Rated'
    movie_df['rated']=='Approved'
]

# %%
outputs = []

# %%
other = select(conditions, outputs)

# %%
movie_df['Other_Rates'] = other

# %%
movie_df['Non_Adult'].head(5)
# Out:
# 0    0
# 1    G
# 2    G
# 3    0
# 4    G
# Name: Non_Adult, dtype: object

# %%
movie_df['Non_Adult'] = non_adult
movie_df.columns
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Index(['title', 'Starring', 'Release dates', 'Running time', 'Country',
#        'Budget', 'Box office', 'Running time (int)', 'Budget (float)',
#        'Box office (float)', 'Release date (datetime)', 'imdb', 'metascore',
#        'rotten_tomatoes', 'Genre', 'runtime', 'director', 'released', 'type',
#        'rated', 'Plot', 'Release date', 'Non_Adult'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
plt.scatter(x=[0.5, 1.5], y=[1,1], s=15000, color=['#06837f', '#fdc100'])
plt.xlim(0,2)
plt.ylim(0.9,1.2)

plt.title('Distribution of Adult and Non Adult Movies', fontsize=18, weight=600, color='#333d29')
plt.text(0.5, 1, '{}\nMovies'.format(str(len(movie_df[movie_df['Non_Adult']!='0']))), va='center', ha='center', fontsize=18, weight=600, color='white')
plt.text(1.5, 1, '{}\nMovies'.format(str(len(movie_df[movie_df['rated']=='R']))), va='center', ha='center', fontsize=18, weight=600, color='white')
plt.text(0.5, 1.11, 'Non Adult', va='center', ha='center', fontsize=17, weight=500, color='#1c2541')
plt.text(1.5, 1.11, 'Adult', va='center', ha='center', fontsize=17, weight=500, color='#1c2541')

plt.axis('off')
plt.show()

# %%
df_plot = df[(df['Budget (float)'] != 0) & (df['Box office (float)'] != 0)]
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plt.suptitle('The Influence of Budget and Revenue\non IMDB rating of Movies', fontsize=18, weight=600, color='#333d29')
for i, col in enumerate(['Budget (float)', 'Box office (float)']):
    sb.regplot(data=df_plot, x=col, y='imdb',
                scatter_kws={"color": "#06837f", "alpha": 0.6}, line_kws={"color": "#fdc100"}, ax=axes[i])

plt.tight_layout()

# %%
ax = sb.jointplot(data=df[(df['Budget (float)'] != 0) & (df['Box office (float)'] != 0)], x='Budget (float)', y='Box office (float)',
                   marker="+", s=100, marginal_kws=dict(bins=20, fill=False), color='#06837f')
ax.fig.suptitle('Budget vs Box Office', fontsize=18, weight=600, color='#333d29')
ax.ax_joint.set_xlim(0, 1e9)
ax.ax_joint.set_ylim(0, 3e9)
ax.ax_joint.axhline((1,1), slope=1, color='#fdc100')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-8b1d53d504ba> in <module>
#       4 ax.ax_joint.set_xlim(0, 1e9)
#       5 ax.ax_joint.set_ylim(0, 3e9)
# ----> 6 ax.ax_joint.axhline((1,1), slope=1, color='#fdc100')
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in axhline(self, y, xmin, xmax, **kwargs)
#     845         self._process_unit_info(ydata=y, kwargs=kwargs)
#     846         yy = self.convert_yunits(y)
# --> 847         scaley = (yy < ymin) or (yy > ymax)
#     848
#     849         trans = self.get_yaxis_transform(which='grid')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.figure(figsize=(12,10))
sb.countplot(y="Running time", data= df2, palette="cool", order= df2['Running time'].value_counts().index[0:15],hue=df['type'])

# %%
sb.kdeplot(data=movie_df['Running time (int)'], shade=True)

# %%
movie_df['Running time'].isna().sum()
# Out:
# 12

# %%
plt.figure(figsize=(15,8))
sb.countplot(x="Country", data=movie_df, palette="Accent", order=movie_df['Country'].value_counts().index[0:15])

# %%
columns=['Genre','Country']
gen_country = df2[columns]

# %%
size = gen_country['Genre'].value_counts()
size
# Out:
# Animation      154
# Adventure      112
# Comedy          96
# Action          56
# Documentary     34
# Drama           20
# nan             17
# Biography       16
# Family           9
# Horror           2
# Short            2
# Crime            2
# Fantasy          1
# Music            1
# Name: Genre, dtype: int64

# %%
# GENRES BY COUNTRIES
import squarify
plt.figure(figsize=(30,15))
squarify.plot(value= gen_country['Genre'], label= gen_country['Country'], sizes= size, alpha=0.8)
plt.rc('font', size=14)
plt.show()

# %%
df2.head(3)
# Out:
#                              title  \
# 0  Snow White and the Seven Dwarfs
# 1                        Pinocchio
# 2                         Fantasia
#
#                                             Starring  \
# 0  ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 1  ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 2              ['Leopold Stokowski', 'Deems Taylor']
#
#                                        Release dates Running time  \
# 0  ['December 21, 1937 ( Carthay Circle Theatre )...   83 minutes
# 1  ['February 7, 1940 ( Center Theatre )', 'Febru...   88 minutes
# 2                                                NaN  126 minutes
#
#          Country         Budget  \
# 0  United States  $1.49 million
# 1  United States   $2.6 million
# 2  United States  $2.28 million
#
#                                        Box office  Running time (int)  \
# 0                                    $418 million                83.0
# ...

# %%
from collections import Counter

# %%
genres_list = []
for i in df['genre']:
    genres_list.extend(str(i).split(', '))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,6))

df_plot = pd.DataFrame(Counter(genres_list).most_common(5), columns=['genre', 'total'])
ax = sb.barplot(data=df_plot, x='genre', y='total', ax=axes[0], palette=['#06837f', '#02cecb', '#b4ffff', '#f8e16c', '#fed811'])
ax.set_title('Top 5 Genres in Movies', fontsize=18, weight=600, color='#333d29')
sb.despine()

df_plot_full = pd.DataFrame([Counter(genres_list)]).transpose().sort_values(by=0, ascending=False)
df_plot.loc[len(df_plot)] = {'genre': 'Others', 'total':df_plot_full[6:].sum()[0]}
plt.title('Percentage Ratio of Movie Genres', fontsize=18, weight=600, color='#333d29')
wedges, texts, autotexts = axes[1].pie(x=df_plot['total'], labels=df_plot['genre'], autopct='%.2f%%',
                                       textprops=dict(fontsize=14), explode=[0,0,0,0,0,0.1], colors=['#06837f', '#02cecb', '#b4ffff', '#f8e16c', '#fed811', '#fdc100'])

for autotext in autotexts:
    autotext.set_color('#1c2541')
    autotext.set_weight('bold')

axes[1].axis('off')
plt.show()

# %%
from wordcloud import WordCloud

# %%
plt.figure(figsize=(20,20))
plt.title('The Most Common Word in Movie Overviews\n', fontsize=30, weight=600, color='#333d29')
wc = WordCloud(max_words=1000, min_font_size=10,
                height=800,width=1600,background_color="white").generate(' '.join(map(str,df['Plot'])))
plt.imshow(wc)

# %% [markdown]
# <h1 style="font-family: Trebuchet MS; padding: 12px; font-size: 30px; color: #081c15; text-align: center; line-height: 1.25;">Movie recommendation</b></span><br><span style="color:blue; font-size: 20px">Using Pandas/Numpy/Cosine similarity</span></h1>
# <hr>

# %%
features=['Genre','Starring','Plot','title']
filters = df2[features]

# %%
def clean_data(x):
        return str.lower(str(x).replace(" ", ""))

# %%
for feature in features:
    filters[feature] = filters[feature].apply(clean_data)
    
filters.head()
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Genre                                           Starring  \
# 0  animation  ['adrianacaselotti','lucillelaverne','harrysto...
# 1  animation  ['cliffedwards','dickiejones','christianrub','...
# 2  animation                 ['leopoldstokowski','deemstaylor']
# 3  animation  ['robertbenchley','francesgifford','buddypeppe...
# 4  animation  ['edwardbrophy','vernafelton','cliffedwards','...
#
#                                                 Plot  \
# 0  exiledintothedangerousforestbyherwickedstepmot...
# 1  alivingpuppet,withthehelpofacricketashisconsci...
# ...

# %%
def create_soup(x):
    return x['Starring'] + ' ' +x['Genre']+' '+ x['Plot']

# %%
filters['soup'] = filters.apply(create_soup, axis=1)
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
filters['soup']
# Out:
# 0      ['adrianacaselotti','lucillelaverne','harrysto...
# 1      ['cliffedwards','dickiejones','christianrub','...
# 2      ['leopoldstokowski','deemstaylor'] animation a...
# 3      ['robertbenchley','francesgifford','buddypeppe...
# 4      ['edwardbrophy','vernafelton','cliffedwards','...
#                              ...
# 517    ['philharris','evagabor','sterlingholloway','s...
# 518    ['rickiesorensen','karlswenson','juniusmatthew...
# 519    ['maewhitman','lucyliu','raven-symoné','meganh...
# 520    ['billcampbell','alanarkin','jenniferconnelly'...
# 521    ['daisyridley','tildacobham-hervey'] biography...
# Name: soup, Length: 522, dtype: object

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(filters['soup'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
filters.sort_values(by='Genre').head(60)
# Out:
#          Genre                                           Starring  \
# 330     action                                                nan
# 187     action  ['charliesheen','kiefersutherland',"chriso'don...
# 400     action  ['johnnydepp','armiehammer','tomwilkinson','wi...
# 202     action  ['dannyglover','rayliotta','denisleary','douge...
# 208     action  ['timcurry','davegoelz','stevewhitmire','jerry...
# 213     action  ['emilioestevez','jeffreynordling','heidikling...
# 215     action  ['christinaricci','douge.doug','georgedzundza'...
# 478     action  ['dwaynejohnson','emilyblunt','édgarramírez','...
# 217     action  ['rickmoranis','evegordon','bughall','robinbar...
# 388     action  ['taylorkitsch','lynncollins','samanthamorton'...
# 503     action  ['alexandermolony','everanderson','yarashahidi...
# 230     action  ['billpaxton','charlizetheron','radešerbedžija...
# 381     action  ['johnnydepp','penélopecruz','ianmcshane','kev...
# ...

# %%
# Reset index of our main DataFrame and construct reverse mapping as before
filters=filters.reset_index()
indices = pd.Series(filters.index, index=filters['title'])

# %%
def get_recommendations_new(title, cosine_sim):
    title=title.replace(' ','').lower()
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df2['title'].iloc[movie_indices]

# %%
get_recommendations_new('princeofpersia:thesandsoftime', cosine_sim2)
# Out:
# 366               The Sorcerer's Apprentice
# 96                         The Wild Country
# 330                                Underdog
# 461                                Stargirl
# 18                  The Story of Robin Hood
# 81       The Adventures of Bullwhip Griffin
# 29               The Great Locomotive Chase
# 153                                    Tron
# 191    White Fang 2: Myth of the White Wolf
# 213                    D3: The Mighty Ducks
# Name: title, dtype: object

# %%
get_recommendations_new('piratesofthecaribbean:deadmentellnotales', cosine_sim2)
# Out:
# 381          Pirates of the Caribbean: On Stranger Tides
# 273    Pirates of the Caribbean: The Curse of the Bla...
# 327             Pirates of the Caribbean: At World's End
# 400                                      The Lone Ranger
# 318           Pirates of the Caribbean: Dead Man's Chest
# 96                                      The Wild Country
# 330                                             Underdog
# 461                                             Stargirl
# 18                               The Story of Robin Hood
# 81                    The Adventures of Bullwhip Griffin
# Name: title, dtype: object

# %% [markdown]
# <h1 style="font-family: Trebuchet MS; padding: 12px; font-size: 30px; color: #081c15; text-align: center; line-height: 1.25;"></b></span><br><span style="color:blue; font-size: 20px">Creating a recommendation system using ratings </span></h1>
# <hr>

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv("Movie_Id_Titles")
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df,movie_titles,on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# # EDA
#
# ## Visualization Imports

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %% [markdown]
# ## Recommending Similar Movies

# %%
#Now let's create a matrix that has the user ids on one access and the movie title on another axis.
#Each cell will then consist of the rating the user gave to that movie. Note there will be a lot of NaN values,
#because most people have not seen most of the movies.

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
liarliar_user_ratings = moviemat['Liar Liar (1997)']
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
#We can then use corrwith() method to get correlations between two pandas series:

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
#Now if we sort the dataframe by correlation, we should get the most similar movies, however note that we get some results
#that don't really make sense. This is because there are a lot of movies only watched once by users 
#who also watched star wars (it was the most popular movie).

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Hollow Reed (1996)                                          1.0
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Star Wars (1977)                                            1.0
# Man of the Year (1995)                                      1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                        Correlation  num of ratings
# title
# Liar Liar (1997)          1.000000             485
# Batman Forever (1995)     0.516968             114
# Mask, The (1994)          0.484650             129
# Down Periscope (1996)     0.472681             101
# Con Air (1997)            0.469828             137
